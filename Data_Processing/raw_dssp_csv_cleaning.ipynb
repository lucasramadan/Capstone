# %%
import pandas as pd
import os
from collections import Counter
import json

# %%
# read in 
df = pd.read_csv('../raw_dssp_csv/1i3n.csv')
# replace 'NaN' with '?'
df.fillna(value='?', inplace=True)
# show
df.head(10)
# Out:
#    DSSP PDB CHAIN AA SS 3H 4H 5H BEND CHIR  ...  ON2I ON2E    TCO  KAPPA  \
# 0     1   2     A  A  ?  ?  ?  ?    ?    ?  ...    79 -0.2  0.000  360.0
# 1     2   3     A  E  ?  ?  ?  ?    ?    -  ...    79 -0.2 -0.681  360.0
# 2     3   4     A  K  E  ?  ?  ?    ?    -  ...    80 -0.9 -0.300    2.4
# 3     4   5     A  V  E  ?  ?  ?    ?    -  ...     2 -0.4 -0.993   20.7
# 4     5   6     A  L  E  ?  ?  ?    ?    -  ...     2 -0.5 -0.735   14.2
# 5     6   7     A  V  E  >  ?  ?    ?    -  ...     3 -0.8 -0.945    3.6
# 6     7   8     A  T  E  3  ?  ?    S    +  ...    25 -0.2 -0.651   79.5
# 7     8   9     A  G  T  >  ?  ?    S    +  ...     6 -0.4  0.792   83.3
# 8     9  10     A  G  T  <  ?  ?    ?    +  ...    23 -0.1  0.541   56.7
# 9    10  11     A  A  T  3  ?  ?    S    +  ...    28 -0.2  0.578   88.6
#
#    ALPHA    PHI    PSI  X-CA  Y-CA  Z-CA
# 0  360.0  360.0   -1.4  -4.8   7.2  22.5
# 1 -126.5  -88.8  145.6  -1.4   8.7  21.7
# 2 -131.5  -88.8  174.4   1.3   7.7  24.2
# 3 -141.5 -123.8  122.5   3.8   9.6  26.3
# 4 -164.6  -85.6  131.1   7.4   8.4  26.1
# 5 -159.8 -118.7  106.8   9.2   8.5  29.5
# 6   12.3  -85.0  145.9  13.0   8.2  29.3
# 7  153.9   62.7   25.1  14.9   7.1  32.4
# 8   65.3  -66.2   -9.4  11.4   6.1  33.8
# 9   88.7  -89.4   -9.4  12.8   3.4  36.1
#
# [10 rows x 32 columns]

# %%
df.tail()
# Out:
#      DSSP  PDB CHAIN AA SS 3H 4H 5H BEND CHIR  ...  ON2I ON2E    TCO  KAPPA  \
# 688   689  342     B  S  T  >  ?  ?    S    -  ...    -5 -0.1 -0.042  108.5
# 689   690  343     B  G  T  <  ?  ?    S    -  ...  -143 -0.1 -0.387   73.5
# 690   691  344     B  F  T  3  ?  ?    S    -  ...    -1 -0.3  0.710  115.7
# 691   692  345     B  G  ?  <  ?  ?    ?    ?  ...  -304 -0.0 -0.998  360.0
# 692   693  346     B  T  ?  ?  ?  ?    ?    ?  ...    -2 -0.0  0.187  360.0
#
#      ALPHA    PHI    PSI  X-CA  Y-CA  Z-CA
# 688 -122.3 -122.1   32.4  33.9  30.0 -10.6
# 689  -22.3   65.6 -145.1  35.9  28.9  -7.6
# 690  -58.9  -75.9  -23.9  37.2  25.3  -7.8
# 691  360.0  173.3 -170.4  34.7  24.0 -10.3
# 692  360.0 -145.7  360.0  31.3  23.2 -11.7
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (693, 32)

# %%
# drop '!*' rows
# df = df.drop(df[df['AA'] == '!'].index.values)

df = df[df['AA'] != '!']

# %%
df.shape
# Out:
# (692, 32)

# %%
# if !* row was successfully dropped
try:
    df.ix[347]
except: 
    print 'success'
# Out:
# success

# %%
# fix HHTHH structure pattern
def replace_pi(l):
    i = 0
    
    while i < len(l)-4:
        window = ''.join(l[i:i+5])
        
        if window == 'HHTHH':
            l[i:i+5] = 'I'
    
        i += 1
        
    return l

# %%
# replace the "HHTHH" pattern with "IIIII"
df['SS'] = replace_pi(df['SS'])

# %%
# replace the '?' with 'C'
df['SS'] = df['SS'].apply(lambda aa: 'C' if aa=='?' else aa)

# %%
df.head(10)
# Out:
#    DSSP PDB CHAIN AA SS 3H 4H 5H BEND CHIR  ...  ON2I ON2E    TCO  KAPPA  \
# 0     1   2     A  A  C  ?  ?  ?    ?    ?  ...    79 -0.2  0.000  360.0
# 1     2   3     A  E  C  ?  ?  ?    ?    -  ...    79 -0.2 -0.681  360.0
# 2     3   4     A  K  E  ?  ?  ?    ?    -  ...    80 -0.9 -0.300    2.4
# 3     4   5     A  V  E  ?  ?  ?    ?    -  ...     2 -0.4 -0.993   20.7
# 4     5   6     A  L  E  ?  ?  ?    ?    -  ...     2 -0.5 -0.735   14.2
# 5     6   7     A  V  E  >  ?  ?    ?    -  ...     3 -0.8 -0.945    3.6
# 6     7   8     A  T  E  3  ?  ?    S    +  ...    25 -0.2 -0.651   79.5
# 7     8   9     A  G  T  >  ?  ?    S    +  ...     6 -0.4  0.792   83.3
# 8     9  10     A  G  T  <  ?  ?    ?    +  ...    23 -0.1  0.541   56.7
# 9    10  11     A  A  T  3  ?  ?    S    +  ...    28 -0.2  0.578   88.6
#
#    ALPHA    PHI    PSI  X-CA  Y-CA  Z-CA
# 0  360.0  360.0   -1.4  -4.8   7.2  22.5
# 1 -126.5  -88.8  145.6  -1.4   8.7  21.7
# 2 -131.5  -88.8  174.4   1.3   7.7  24.2
# 3 -141.5 -123.8  122.5   3.8   9.6  26.3
# 4 -164.6  -85.6  131.1   7.4   8.4  26.1
# 5 -159.8 -118.7  106.8   9.2   8.5  29.5
# 6   12.3  -85.0  145.9  13.0   8.2  29.3
# 7  153.9   62.7   25.1  14.9   7.1  32.4
# 8   65.3  -66.2   -9.4  11.4   6.1  33.8
# 9   88.7  -89.4   -9.4  12.8   3.4  36.1
#
# [10 rows x 32 columns]

# %%
Counter(df['SS'].values)
# Out:
# Counter({'B': 8,
#          'C': 152,
#          'E': 120,
#          'G': 11,
#          'H': 254,
#          'I': 5,
#          'S': 81,
#          'T': 61})

# %% [markdown]
# ## Now for all of the dssp_csv files

# %%
from __future__ import print_function

# %%
topdir, _, files = next(os.walk('../raw_dssp_csv/'))

# %%
for i, fi in enumerate(files):
    # show progress
    print('\r On protein #'+str(i), end='')
    
    # read in the csv
    df = pd.read_csv(topdir+fi)
    
    # replace NaN with ?
    df.fillna(value='?', inplace=True)
    
    # drop !* rows
    df = df[df['AA'] != '!']
    
    # replace "HHTHH" pi helix pattern 
    df['SS'] = replace_pi(df['SS'])
    
    # replace '?' SS with 'C'
    df['SS'] = df['SS'].apply(lambda aa: 'C' if aa == '?' else aa)
    
    # write to csv
    df.to_csv('../clean_dssp_csv/'+fi, index=False)
# Out:
#  On protein #0
# /Users/LucasRamadan/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#  On protein #346
